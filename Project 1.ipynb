# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv') 
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# 2      Female             28     28.0  NaN   NaN       NaN
# 3  Both sexes             23     23.0  NaN   NaN       NaN
# 4      Female             78     78.0  NaN   NaN       NaN

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv') 
df1.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# 3 -9999 -9999
# 4 -9999 -9999
#
# [5 rows x 21 columns]

# %%
# Metadata from the files

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# memory usage: 18.8+ MB

# %%
# 2. row names from the above files

np.ravel(df.index)
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655])

# %%
np.ravel(df.index).dtype
# Out:
# dtype('int64')

# %%
np.ravel(df1.index)
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207])

# %%
np.ravel(df1.index).dtype
# Out:
# dtype('int64')

# %%
# 3. Change the column name from any of the above file
df.rename(index=str, columns={"Indicator": "Indicator_id"})
# Out:
#                                          Indicator_id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# 11                   Life expectancy at birth (years)      Published  2012
# 12                  Life expectancy at age 60 (years)      Published  2012
# 13                   Life expectancy at birth (years)      Published  2012
# 14                   Life expectancy at birth (years)      Published  2000
# 15                   Life expectancy at birth (years)      Published  1990
# 16                  Life expectancy at age 60 (years)      Published  1990
# 17                   Life expectancy at birth (years)      Published  2012
# 18                  Life expectancy at age 60 (years)      Published  2000
# 19                   Life expectancy at birth (years)      Published  1990
# 20                  Life expectancy at age 60 (years)      Published  2012
# 21                  Life expectancy at age 60 (years)      Published  2012
# 22                  Life expectancy at age 60 (years)      Published  1990
# 23                  Life expectancy at age 60 (years)      Published  2000
# 24                  Life expectancy at age 60 (years)      Published  2012
# 25                   Life expectancy at birth (years)      Published  2000
# 26                  Life expectancy at age 60 (years)      Published  2000
# 27                  Life expectancy at age 60 (years)      Published  1990
# 28                   Life expectancy at birth (years)      Published  1990
# 29                   Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4626  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4627  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4628  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4629  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4630  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4631  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4632  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4633  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4634  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4635  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4636  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4637  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4638  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4639  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4640  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4641  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4642  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4643  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4644  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4645  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4646  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4647  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4648  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4649  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4650  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
#                  WHO region World Bank income group  \
# 0                    Europe             High-income
# 1                    Europe             High-income
# 2                    Europe             High-income
# 3                    Europe             High-income
# 4     Eastern Mediterranean             High-income
# 5                  Americas             High-income
# 6                  Americas             High-income
# 7                  Americas             High-income
# 8           Western Pacific             High-income
# 9           Western Pacific             High-income
# 10          Western Pacific             High-income
# 11                   Europe             High-income
# 12                   Europe             High-income
# 13                   Europe             High-income
# 14    Eastern Mediterranean             High-income
# 15    Eastern Mediterranean             High-income
# 16    Eastern Mediterranean             High-income
# 17                 Americas             High-income
# 18                 Americas             High-income
# 19                 Americas             High-income
# 20                 Americas             High-income
# 21                 Americas             High-income
# 22          Western Pacific             High-income
# 23          Western Pacific             High-income
# 24          Western Pacific             High-income
# 25                 Americas             High-income
# 26                 Americas             High-income
# 27                 Americas             High-income
# 28                   Europe             High-income
# 29                   Europe             High-income
# ...                     ...                     ...
# 4626                 Europe     Upper-middle-income
# 4627               Americas     Upper-middle-income
# 4628                 Europe             High-income
# 4629                 Africa     Lower-middle-income
# 4630                 Africa     Upper-middle-income
# 4631  Eastern Mediterranean     Lower-middle-income
# 4632                 Africa              Low-income
# 4633        South-East Asia     Lower-middle-income
# 4634        South-East Asia     Lower-middle-income
# 4635                 Europe              Low-income
# 4636                 Europe              Low-income
# 4637        Western Pacific     Lower-middle-income
# 4638               Americas             High-income
# 4639               Americas             High-income
# 4640  Eastern Mediterranean     Lower-middle-income
# 4641        Western Pacific     Upper-middle-income
# 4642                 Africa              Low-income
# 4643                 Europe     Lower-middle-income
# 4644               Americas     Upper-middle-income
# 4645               Americas     Upper-middle-income
# 4646               Americas     Upper-middle-income
# 4647               Americas     Upper-middle-income
# 4648               Americas     Upper-middle-income
# 4649        Western Pacific     Lower-middle-income
# 4650        Western Pacific     Lower-middle-income
# 4651        Western Pacific     Lower-middle-income
# 4652  Eastern Mediterranean              Low-income
# 4653                 Africa     Upper-middle-income
# 4654                 Africa              Low-income
# 4655                 Africa              Low-income
#
#                                  Country         Sex  Display Value  Numeric  \
# 0                                Andorra  Both sexes             77     77.0
# 1                                Andorra  Both sexes             80     80.0
# 2                                Andorra      Female             28     28.0
# 3                                Andorra  Both sexes             23     23.0
# 4                   United Arab Emirates      Female             78     78.0
# 5                    Antigua and Barbuda        Male             72     72.0
# 6                    Antigua and Barbuda        Male             17     17.0
# 7                    Antigua and Barbuda  Both sexes             22     22.0
# 8                              Australia        Male             81     81.0
# 9                              Australia  Both sexes             80     80.0
# 10                             Australia  Both sexes             83     83.0
# 11                               Austria      Female             83     83.0
# 12                               Austria      Female             25     25.0
# 13                               Belgium      Female             83     83.0
# 14                               Bahrain        Male             73     73.0
# 15                               Bahrain      Female             74     74.0
# 16                               Bahrain        Male             17     17.0
# 17                               Bahamas        Male             72     72.0
# 18                               Bahamas  Both sexes             21     21.0
# 19                              Barbados        Male             71     71.0
# 20                              Barbados      Female             25     25.0
# 21                              Barbados  Both sexes             23     23.0
# 22                     Brunei Darussalam      Female             20     20.0
# 23                     Brunei Darussalam      Female             22     22.0
# 24                     Brunei Darussalam      Female             21     21.0
# 25                                Canada      Female             82     82.0
# 26                                Canada        Male             21     21.0
# 27                                Canada      Female             24     24.0
# 28                           Switzerland        Male             74     74.0
# 29                           Switzerland  Both sexes             83     83.0
# ...                                  ...         ...            ...      ...
# 4626                              Serbia      Female             67     67.0
# 4627                            Suriname  Both sexes             66     66.0
# 4628                              Sweden  Both sexes             72     72.0
# 4629                           Swaziland      Female             47     47.0
# 4630                          Seychelles        Male             61     61.0
# 4631                Syrian Arab Republic      Female             64     64.0
# 4632                                Chad      Female             44     44.0
# 4633                            Thailand        Male             59     59.0
# 4634                            Thailand      Female             65     65.0
# 4635                          Tajikistan  Both sexes             56     56.0
# 4636                          Tajikistan      Female             60     60.0
# 4637                               Tonga      Female             61     61.0
# 4638                 Trinidad and Tobago      Female             64     64.0
# 4639                 Trinidad and Tobago  Both sexes             61     61.0
# 4640                             Tunisia        Male             63     63.0
# 4641                              Tuvalu        Male             57     57.0
# 4642                              Uganda      Female             40     40.0
# 4643                             Ukraine  Both sexes             60     60.0
# 4644                             Uruguay        Male             65     65.0
# 4645                             Uruguay      Female             70     70.0
# 4646                             Uruguay  Both sexes             68     68.0
# 4647    Saint Vincent and the Grenadines  Both sexes             61     61.0
# 4648  Venezuela (Bolivarian Republic of)  Both sexes             66     66.0
# 4649                             Vanuatu        Male             59     59.0
# 4650                               Samoa        Male             62     62.0
# 4651                               Samoa      Female             66     66.0
# 4652                               Yemen  Both sexes             54     54.0
# 4653                        South Africa        Male             49     49.0
# 4654                              Zambia  Both sexes             36     36.0
# 4655                            Zimbabwe      Female             51     51.0
#
#       Low  High  Comments
# 0     NaN   NaN       NaN
# 1     NaN   NaN       NaN
# 2     NaN   NaN       NaN
# 3     NaN   NaN       NaN
# 4     NaN   NaN       NaN
# 5     NaN   NaN       NaN
# 6     NaN   NaN       NaN
# 7     NaN   NaN       NaN
# 8     NaN   NaN       NaN
# 9     NaN   NaN       NaN
# 10    NaN   NaN       NaN
# 11    NaN   NaN       NaN
# 12    NaN   NaN       NaN
# 13    NaN   NaN       NaN
# 14    NaN   NaN       NaN
# 15    NaN   NaN       NaN
# 16    NaN   NaN       NaN
# 17    NaN   NaN       NaN
# 18    NaN   NaN       NaN
# 19    NaN   NaN       NaN
# 20    NaN   NaN       NaN
# 21    NaN   NaN       NaN
# 22    NaN   NaN       NaN
# 23    NaN   NaN       NaN
# 24    NaN   NaN       NaN
# 25    NaN   NaN       NaN
# 26    NaN   NaN       NaN
# 27    NaN   NaN       NaN
# 28    NaN   NaN       NaN
# 29    NaN   NaN       NaN
# ...   ...   ...       ...
# 4626  NaN   NaN       NaN
# 4627  NaN   NaN       NaN
# 4628  NaN   NaN       NaN
# 4629  NaN   NaN       NaN
# 4630  NaN   NaN       NaN
# 4631  NaN   NaN       NaN
# 4632  NaN   NaN       NaN
# 4633  NaN   NaN       NaN
# 4634  NaN   NaN       NaN
# 4635  NaN   NaN       NaN
# 4636  NaN   NaN       NaN
# 4637  NaN   NaN       NaN
# 4638  NaN   NaN       NaN
# 4639  NaN   NaN       NaN
# 4640  NaN   NaN       NaN
# 4641  NaN   NaN       NaN
# 4642  NaN   NaN       NaN
# 4643  NaN   NaN       NaN
# 4644  NaN   NaN       NaN
# 4645  NaN   NaN       NaN
# 4646  NaN   NaN       NaN
# 4647  NaN   NaN       NaN
# 4648  NaN   NaN       NaN
# 4649  NaN   NaN       NaN
# 4650  NaN   NaN       NaN
# 4651  NaN   NaN       NaN
# 4652  NaN   NaN       NaN
# 4653  NaN   NaN       NaN
# 4654  NaN   NaN       NaN
# 4655  NaN   NaN       NaN
#
# [4656 rows x 12 columns]

# %%
# 4. Change the column name from any of the above file and store the changes made permanently.
df.rename(index=str, columns={"Indicator": "Indicator_id"},inplace=True)

# %%
df
# Out:
#                                          Indicator_id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# 11                   Life expectancy at birth (years)      Published  2012
# 12                  Life expectancy at age 60 (years)      Published  2012
# 13                   Life expectancy at birth (years)      Published  2012
# 14                   Life expectancy at birth (years)      Published  2000
# 15                   Life expectancy at birth (years)      Published  1990
# 16                  Life expectancy at age 60 (years)      Published  1990
# 17                   Life expectancy at birth (years)      Published  2012
# 18                  Life expectancy at age 60 (years)      Published  2000
# 19                   Life expectancy at birth (years)      Published  1990
# 20                  Life expectancy at age 60 (years)      Published  2012
# 21                  Life expectancy at age 60 (years)      Published  2012
# 22                  Life expectancy at age 60 (years)      Published  1990
# 23                  Life expectancy at age 60 (years)      Published  2000
# 24                  Life expectancy at age 60 (years)      Published  2012
# 25                   Life expectancy at birth (years)      Published  2000
# 26                  Life expectancy at age 60 (years)      Published  2000
# 27                  Life expectancy at age 60 (years)      Published  1990
# 28                   Life expectancy at birth (years)      Published  1990
# 29                   Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4626  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4627  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4628  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4629  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4630  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4631  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4632  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4633  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4634  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4635  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4636  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4637  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4638  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4639  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4640  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4641  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4642  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4643  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4644  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4645  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4646  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4647  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4648  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4649  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4650  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
#                  WHO region World Bank income group  \
# 0                    Europe             High-income
# 1                    Europe             High-income
# 2                    Europe             High-income
# 3                    Europe             High-income
# 4     Eastern Mediterranean             High-income
# 5                  Americas             High-income
# 6                  Americas             High-income
# 7                  Americas             High-income
# 8           Western Pacific             High-income
# 9           Western Pacific             High-income
# 10          Western Pacific             High-income
# 11                   Europe             High-income
# 12                   Europe             High-income
# 13                   Europe             High-income
# 14    Eastern Mediterranean             High-income
# 15    Eastern Mediterranean             High-income
# 16    Eastern Mediterranean             High-income
# 17                 Americas             High-income
# 18                 Americas             High-income
# 19                 Americas             High-income
# 20                 Americas             High-income
# 21                 Americas             High-income
# 22          Western Pacific             High-income
# 23          Western Pacific             High-income
# 24          Western Pacific             High-income
# 25                 Americas             High-income
# 26                 Americas             High-income
# 27                 Americas             High-income
# 28                   Europe             High-income
# 29                   Europe             High-income
# ...                     ...                     ...
# 4626                 Europe     Upper-middle-income
# 4627               Americas     Upper-middle-income
# 4628                 Europe             High-income
# 4629                 Africa     Lower-middle-income
# 4630                 Africa     Upper-middle-income
# 4631  Eastern Mediterranean     Lower-middle-income
# 4632                 Africa              Low-income
# 4633        South-East Asia     Lower-middle-income
# 4634        South-East Asia     Lower-middle-income
# 4635                 Europe              Low-income
# 4636                 Europe              Low-income
# 4637        Western Pacific     Lower-middle-income
# 4638               Americas             High-income
# 4639               Americas             High-income
# 4640  Eastern Mediterranean     Lower-middle-income
# 4641        Western Pacific     Upper-middle-income
# 4642                 Africa              Low-income
# 4643                 Europe     Lower-middle-income
# 4644               Americas     Upper-middle-income
# 4645               Americas     Upper-middle-income
# 4646               Americas     Upper-middle-income
# 4647               Americas     Upper-middle-income
# 4648               Americas     Upper-middle-income
# 4649        Western Pacific     Lower-middle-income
# 4650        Western Pacific     Lower-middle-income
# 4651        Western Pacific     Lower-middle-income
# 4652  Eastern Mediterranean              Low-income
# 4653                 Africa     Upper-middle-income
# 4654                 Africa              Low-income
# 4655                 Africa              Low-income
#
#                                  Country         Sex  Display Value  Numeric  \
# 0                                Andorra  Both sexes             77     77.0
# 1                                Andorra  Both sexes             80     80.0
# 2                                Andorra      Female             28     28.0
# 3                                Andorra  Both sexes             23     23.0
# 4                   United Arab Emirates      Female             78     78.0
# 5                    Antigua and Barbuda        Male             72     72.0
# 6                    Antigua and Barbuda        Male             17     17.0
# 7                    Antigua and Barbuda  Both sexes             22     22.0
# 8                              Australia        Male             81     81.0
# 9                              Australia  Both sexes             80     80.0
# 10                             Australia  Both sexes             83     83.0
# 11                               Austria      Female             83     83.0
# 12                               Austria      Female             25     25.0
# 13                               Belgium      Female             83     83.0
# 14                               Bahrain        Male             73     73.0
# 15                               Bahrain      Female             74     74.0
# 16                               Bahrain        Male             17     17.0
# 17                               Bahamas        Male             72     72.0
# 18                               Bahamas  Both sexes             21     21.0
# 19                              Barbados        Male             71     71.0
# 20                              Barbados      Female             25     25.0
# 21                              Barbados  Both sexes             23     23.0
# 22                     Brunei Darussalam      Female             20     20.0
# 23                     Brunei Darussalam      Female             22     22.0
# 24                     Brunei Darussalam      Female             21     21.0
# 25                                Canada      Female             82     82.0
# 26                                Canada        Male             21     21.0
# 27                                Canada      Female             24     24.0
# 28                           Switzerland        Male             74     74.0
# 29                           Switzerland  Both sexes             83     83.0
# ...                                  ...         ...            ...      ...
# 4626                              Serbia      Female             67     67.0
# 4627                            Suriname  Both sexes             66     66.0
# 4628                              Sweden  Both sexes             72     72.0
# 4629                           Swaziland      Female             47     47.0
# 4630                          Seychelles        Male             61     61.0
# 4631                Syrian Arab Republic      Female             64     64.0
# 4632                                Chad      Female             44     44.0
# 4633                            Thailand        Male             59     59.0
# 4634                            Thailand      Female             65     65.0
# 4635                          Tajikistan  Both sexes             56     56.0
# 4636                          Tajikistan      Female             60     60.0
# 4637                               Tonga      Female             61     61.0
# 4638                 Trinidad and Tobago      Female             64     64.0
# 4639                 Trinidad and Tobago  Both sexes             61     61.0
# 4640                             Tunisia        Male             63     63.0
# 4641                              Tuvalu        Male             57     57.0
# 4642                              Uganda      Female             40     40.0
# 4643                             Ukraine  Both sexes             60     60.0
# 4644                             Uruguay        Male             65     65.0
# 4645                             Uruguay      Female             70     70.0
# 4646                             Uruguay  Both sexes             68     68.0
# 4647    Saint Vincent and the Grenadines  Both sexes             61     61.0
# 4648  Venezuela (Bolivarian Republic of)  Both sexes             66     66.0
# 4649                             Vanuatu        Male             59     59.0
# 4650                               Samoa        Male             62     62.0
# 4651                               Samoa      Female             66     66.0
# 4652                               Yemen  Both sexes             54     54.0
# 4653                        South Africa        Male             49     49.0
# 4654                              Zambia  Both sexes             36     36.0
# 4655                            Zimbabwe      Female             51     51.0
#
#       Low  High  Comments
# 0     NaN   NaN       NaN
# 1     NaN   NaN       NaN
# 2     NaN   NaN       NaN
# 3     NaN   NaN       NaN
# 4     NaN   NaN       NaN
# 5     NaN   NaN       NaN
# 6     NaN   NaN       NaN
# 7     NaN   NaN       NaN
# 8     NaN   NaN       NaN
# 9     NaN   NaN       NaN
# 10    NaN   NaN       NaN
# 11    NaN   NaN       NaN
# 12    NaN   NaN       NaN
# 13    NaN   NaN       NaN
# 14    NaN   NaN       NaN
# 15    NaN   NaN       NaN
# 16    NaN   NaN       NaN
# 17    NaN   NaN       NaN
# 18    NaN   NaN       NaN
# 19    NaN   NaN       NaN
# 20    NaN   NaN       NaN
# 21    NaN   NaN       NaN
# 22    NaN   NaN       NaN
# 23    NaN   NaN       NaN
# 24    NaN   NaN       NaN
# 25    NaN   NaN       NaN
# 26    NaN   NaN       NaN
# 27    NaN   NaN       NaN
# 28    NaN   NaN       NaN
# 29    NaN   NaN       NaN
# ...   ...   ...       ...
# 4626  NaN   NaN       NaN
# 4627  NaN   NaN       NaN
# 4628  NaN   NaN       NaN
# 4629  NaN   NaN       NaN
# 4630  NaN   NaN       NaN
# 4631  NaN   NaN       NaN
# 4632  NaN   NaN       NaN
# 4633  NaN   NaN       NaN
# 4634  NaN   NaN       NaN
# 4635  NaN   NaN       NaN
# 4636  NaN   NaN       NaN
# 4637  NaN   NaN       NaN
# 4638  NaN   NaN       NaN
# 4639  NaN   NaN       NaN
# 4640  NaN   NaN       NaN
# 4641  NaN   NaN       NaN
# 4642  NaN   NaN       NaN
# 4643  NaN   NaN       NaN
# 4644  NaN   NaN       NaN
# 4645  NaN   NaN       NaN
# 4646  NaN   NaN       NaN
# 4647  NaN   NaN       NaN
# 4648  NaN   NaN       NaN
# 4649  NaN   NaN       NaN
# 4650  NaN   NaN       NaN
# 4651  NaN   NaN       NaN
# 4652  NaN   NaN       NaN
# 4653  NaN   NaN       NaN
# 4654  NaN   NaN       NaN
# 4655  NaN   NaN       NaN
#
# [4656 rows x 12 columns]

# %%
# 5. Change the names of multiple columns.

# %%
df.rename(index=str, columns={"PUBLISH STATES": "Publication_status","WHO region": "WHO_region ","Display Value":"Display_value"},inplace=True)

# %%
df.head()
# Out:
#                         Indicator_id Publication_status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#              WHO_region  World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display_value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# 2      Female             28     28.0  NaN   NaN       NaN
# 3  Both sexes             23     23.0  NaN   NaN       NaN
# 4      Female             78     78.0  NaN   NaN       NaN

# %%
# 6. Arrange values of a particular column in ascending order

# %%
df.sort_values(by=['Year'])
# Out:
#                                          Indicator_id Publication_status  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# 1253                 Life expectancy at birth (years)          Published
# 1247                Life expectancy at age 60 (years)          Published
# 3219                Life expectancy at age 60 (years)          Published
# 3226                 Life expectancy at birth (years)          Published
# 1240                Life expectancy at age 60 (years)          Published
# 1239                 Life expectancy at birth (years)          Published
# 1238                 Life expectancy at birth (years)          Published
# 1237                 Life expectancy at birth (years)          Published
# 1236                 Life expectancy at birth (years)          Published
# 3207                 Life expectancy at birth (years)          Published
# 3231                 Life expectancy at birth (years)          Published
# 3188                Life expectancy at age 60 (years)          Published
# 1277                 Life expectancy at birth (years)          Published
# 1302                 Life expectancy at birth (years)          Published
# 3158                 Life expectancy at birth (years)          Published
# 1300                 Life expectancy at birth (years)          Published
# 3159                Life expectancy at age 60 (years)          Published
# 3160                Life expectancy at age 60 (years)          Published
# ...                                               ...                ...
# 3175                Life expectancy at age 60 (years)          Published
# 3174                 Life expectancy at birth (years)          Published
# 1285                 Life expectancy at birth (years)          Published
# 1286                Life expectancy at age 60 (years)          Published
# 3171                 Life expectancy at birth (years)          Published
# 1288                Life expectancy at age 60 (years)          Published
# 1290                Life expectancy at age 60 (years)          Published
# 1292                 Life expectancy at birth (years)          Published
# 3166                Life expectancy at age 60 (years)          Published
# 3165                 Life expectancy at birth (years)          Published
# 3163                Life expectancy at age 60 (years)          Published
# 3162                 Life expectancy at birth (years)          Published
# 1301                Life expectancy at age 60 (years)          Published
# 3137                 Life expectancy at birth (years)          Published
# 1303                 Life expectancy at birth (years)          Published
# 3155                 Life expectancy at birth (years)          Published
# 3154                Life expectancy at age 60 (years)          Published
# 1304                Life expectancy at age 60 (years)          Published
# 1306                 Life expectancy at birth (years)          Published
# 3150                Life expectancy at age 60 (years)          Published
# 3148                 Life expectancy at birth (years)          Published
# 3147                Life expectancy at age 60 (years)          Published
# 3146                 Life expectancy at birth (years)          Published
# 3145                 Life expectancy at birth (years)          Published
# 1309                Life expectancy at age 60 (years)          Published
# 1316                 Life expectancy at birth (years)          Published
# 3141                 Life expectancy at birth (years)          Published
# 3139                Life expectancy at age 60 (years)          Published
# 3156                Life expectancy at age 60 (years)          Published
# 4655  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year            WHO_region  World Bank income group  \
# 0     1990                 Europe             High-income
# 1270  1990                 Europe             High-income
# 3193  1990                 Europe     Lower-middle-income
# 3194  1990                 Europe     Lower-middle-income
# 3197  1990                 Europe     Lower-middle-income
# 1264  1990                 Europe             High-income
# 3199  1990                 Europe     Lower-middle-income
# 1262  1990        Western Pacific             High-income
# 1259  1990        Western Pacific             High-income
# 3203  1990        South-East Asia     Lower-middle-income
# 1273  1990                 Europe             High-income
# 3204  1990        Western Pacific     Lower-middle-income
# 1253  1990        Western Pacific             High-income
# 1247  1990               Americas             High-income
# 3219  1990        Western Pacific     Lower-middle-income
# 3226  1990                 Europe     Upper-middle-income
# 1240  1990                 Europe             High-income
# 1239  1990                 Europe             High-income
# 1238  1990                 Europe             High-income
# 1237  1990                 Europe             High-income
# 1236  1990                 Europe             High-income
# 3207  1990        Western Pacific     Lower-middle-income
# 3231  1990                 Europe     Upper-middle-income
# 3188  1990                 Africa     Lower-middle-income
# 1277  1990                 Europe             High-income
# 1302  1990                 Europe             High-income
# 3158  1990                 Europe     Lower-middle-income
# 1300  1990                 Europe             High-income
# 3159  1990                 Europe     Lower-middle-income
# 3160  1990               Americas     Lower-middle-income
# ...    ...                    ...                     ...
# 3175  2012  Eastern Mediterranean     Lower-middle-income
# 3174  2012  Eastern Mediterranean     Lower-middle-income
# 1285  2012                 Europe             High-income
# 1286  2012                 Europe             High-income
# 3171  2012  Eastern Mediterranean     Lower-middle-income
# 1288  2012                 Europe             High-income
# 1290  2012                 Europe             High-income
# 1292  2012                 Africa             High-income
# 3166  2012               Americas     Lower-middle-income
# 3165  2012               Americas     Lower-middle-income
# 3163  2012               Americas     Lower-middle-income
# 3162  2012               Americas     Lower-middle-income
# 1301  2012                 Europe             High-income
# 3137  2012                 Africa     Lower-middle-income
# 1303  2012                 Europe             High-income
# 3155  2012        Western Pacific     Lower-middle-income
# 3154  2012  Eastern Mediterranean     Lower-middle-income
# 1304  2012                 Europe             High-income
# 1306  2012                 Europe             High-income
# 3150  2012               Americas     Lower-middle-income
# 3148  2012               Americas     Lower-middle-income
# 3147  2012  Eastern Mediterranean     Lower-middle-income
# 3146  2012  Eastern Mediterranean     Lower-middle-income
# 3145  2012  Eastern Mediterranean     Lower-middle-income
# 1309  2012                 Europe             High-income
# 1316  2012                 Europe             High-income
# 3141  2012                 Africa     Lower-middle-income
# 3139  2012                 Africa     Lower-middle-income
# 3156  2012        Western Pacific     Lower-middle-income
# 4655  2012                 Africa              Low-income
#
#                                                 Country         Sex  \
# 0                                               Andorra  Both sexes
# 1270                                            Germany        Male
# 3193                                Republic of Moldova        Male
# 3194                                Republic of Moldova  Both sexes
# 3197                                Republic of Moldova        Male
# 1264                                             Cyprus  Both sexes
# 3199                                Republic of Moldova  Both sexes
# 1262                                       Cook Islands        Male
# 1259                                       Cook Islands        Male
# 3203                                           Maldives      Female
# 1273                                            Denmark  Both sexes
# 3204                                   Marshall Islands      Female
# 1253                                  Brunei Darussalam  Both sexes
# 1247                                            Bahamas        Male
# 3219                                            Vanuatu  Both sexes
# 3226                                           Bulgaria  Both sexes
# 1240                                            Belgium      Female
# 1239                                            Belgium  Both sexes
# 1238                                            Belgium      Female
# 1237                                            Austria  Both sexes
# 1236                                            Austria        Male
# 3207                                           Mongolia      Female
# 3231                                            Belarus      Female
# 3188                                            Lesotho      Female
# 1277                                            Estonia  Both sexes
# 1302                                            Hungary        Male
# 3158                                            Georgia        Male
# 1300                                            Croatia        Male
# 3159                                            Georgia  Both sexes
# 3160                                          Guatemala      Female
# ...                                                 ...         ...
# 3175                         Iran (Islamic Republic of)        Male
# 3174                         Iran (Islamic Republic of)      Female
# 1285                                             France  Both sexes
# 1286                                             France  Both sexes
# 3171                         Iran (Islamic Republic of)        Male
# 1288  United Kingdom of Great Britain and Northern I...      Female
# 1290  United Kingdom of Great Britain and Northern I...  Both sexes
# 1292                                  Equatorial Guinea      Female
# 3166                                           Honduras        Male
# 3165                                           Honduras  Both sexes
# 3163                                             Guyana        Male
# 3162                                             Guyana      Female
# 1301                                            Croatia  Both sexes
# 3137                                           Cameroon        Male
# 1303                                            Hungary  Both sexes
# 3155                   Micronesia (Federated States of)        Male
# 3154                                              Egypt        Male
# 1304                                            Hungary  Both sexes
# 1306                                            Ireland      Female
# 3150                                            Ecuador        Male
# 3148                                            Ecuador      Female
# 3147                                           Djibouti      Female
# 3146                                           Djibouti  Both sexes
# 3145                                           Djibouti      Female
# 1309                                            Ireland      Female
# 1316                                              Italy  Both sexes
# 3141                                         Cabo Verde  Both sexes
# 3139                                           Cameroon      Female
# 3156                   Micronesia (Federated States of)        Male
# 4655                                           Zimbabwe      Female
#
#       Display_value  Numeric  Low  High  Comments
# 0                77     77.0  NaN   NaN       NaN
# 1270             72     72.0  NaN   NaN       NaN
# 3193             65     65.0  NaN   NaN       NaN
# 3194             68     68.0  NaN   NaN       NaN
# 3197             15     15.0  NaN   NaN       NaN
# 1264             76     76.0  NaN   NaN       NaN
# 3199             17     17.0  NaN   NaN       NaN
# 1262             17     17.0  NaN   NaN       NaN
# 1259             67     67.0  NaN   NaN       NaN
# 3203             12     12.0  NaN   NaN       NaN
# 1273             20     20.0  NaN   NaN       NaN
# 3204             65     65.0  NaN   NaN       NaN
# 1253             73     73.0  NaN   NaN       NaN
# 1247             17     17.0  NaN   NaN       NaN
# 3219             16     16.0  NaN   NaN       NaN
# 3226             71     71.0  NaN   NaN       NaN
# 1240             23     23.0  NaN   NaN       NaN
# 1239             76     76.0  NaN   NaN       NaN
# 1238             79     79.0  NaN   NaN       NaN
# 1237             76     76.0  NaN   NaN       NaN
# 1236             72     72.0  NaN   NaN       NaN
# 3207             64     64.0  NaN   NaN       NaN
# 3231             76     76.0  NaN   NaN       NaN
# 3188             17     17.0  NaN   NaN       NaN
# 1277             70     70.0  NaN   NaN       NaN
# 1302             65     65.0  NaN   NaN       NaN
# 3158             67     67.0  NaN   NaN       NaN
# 1300             69     69.0  NaN   NaN       NaN
# 3159             19     19.0  NaN   NaN       NaN
# 3160             19     19.0  NaN   NaN       NaN
# ...             ...      ...  ...   ...       ...
# 3175             19     19.0  NaN   NaN       NaN
# 3174             76     76.0  NaN   NaN       NaN
# 1285             82     82.0  NaN   NaN       NaN
# 1286             25     25.0  NaN   NaN       NaN
# 3171             72     72.0  NaN   NaN       NaN
# 1288             25     25.0  NaN   NaN       NaN
# 1290             24     24.0  NaN   NaN       NaN
# 1292             57     57.0  NaN   NaN       NaN
# 3166             21     21.0  NaN   NaN       NaN
# 3165             74     74.0  NaN   NaN       NaN
# 3163             13     13.0  NaN   NaN       NaN
# 3162             67     67.0  NaN   NaN       NaN
# 1301             21     21.0  NaN   NaN       NaN
# 3137             55     55.0  NaN   NaN       NaN
# 1303             75     75.0  NaN   NaN       NaN
# 3155             68     68.0  NaN   NaN       NaN
# 3154             16     16.0  NaN   NaN       NaN
# 1304             20     20.0  NaN   NaN       NaN
# 1306             83     83.0  NaN   NaN       NaN
# 3150             21     21.0  NaN   NaN       NaN
# 3148             78     78.0  NaN   NaN       NaN
# 3147             17     17.0  NaN   NaN       NaN
# 3146             61     61.0  NaN   NaN       NaN
# 3145             63     63.0  NaN   NaN       NaN
# 1309             25     25.0  NaN   NaN       NaN
# 1316             83     83.0  NaN   NaN       NaN
# 3141             74     74.0  NaN   NaN       NaN
# 3139             17     17.0  NaN   NaN       NaN
# 3156             16     16.0  NaN   NaN       NaN
# 4655             51     51.0  NaN   NaN       NaN
#
# [4656 rows x 12 columns]

# %%
# 7. Arrange multiple column values in ascending order.

# %%
df.sort_values(by=['Year', 'Display_value'])
# Out:
#                            Indicator_id Publication_status  Year  \
# 1474  Life expectancy at age 60 (years)          Published  1990
# 1476  Life expectancy at age 60 (years)          Published  1990
# 1813  Life expectancy at age 60 (years)          Published  1990
# 3071  Life expectancy at age 60 (years)          Published  1990
# 577   Life expectancy at age 60 (years)          Published  1990
# 3203  Life expectancy at age 60 (years)          Published  1990
# 4275  Life expectancy at age 60 (years)          Published  1990
# 604   Life expectancy at age 60 (years)          Published  1990
# 686   Life expectancy at age 60 (years)          Published  1990
# 991   Life expectancy at age 60 (years)          Published  1990
# 1181  Life expectancy at age 60 (years)          Published  1990
# 1631  Life expectancy at age 60 (years)          Published  1990
# 1899  Life expectancy at age 60 (years)          Published  1990
# 2033  Life expectancy at age 60 (years)          Published  1990
# 2959  Life expectancy at age 60 (years)          Published  1990
# 3079  Life expectancy at age 60 (years)          Published  1990
# 3675  Life expectancy at age 60 (years)          Published  1990
# 4454  Life expectancy at age 60 (years)          Published  1990
# 177   Life expectancy at age 60 (years)          Published  1990
# 242   Life expectancy at age 60 (years)          Published  1990
# 252   Life expectancy at age 60 (years)          Published  1990
# 563   Life expectancy at age 60 (years)          Published  1990
# 565   Life expectancy at age 60 (years)          Published  1990
# 574   Life expectancy at age 60 (years)          Published  1990
# 613   Life expectancy at age 60 (years)          Published  1990
# 649   Life expectancy at age 60 (years)          Published  1990
# 783   Life expectancy at age 60 (years)          Published  1990
# 968   Life expectancy at age 60 (years)          Published  1990
# 982   Life expectancy at age 60 (years)          Published  1990
# 993   Life expectancy at age 60 (years)          Published  1990
# ...                                 ...                ...   ...
# 1340   Life expectancy at birth (years)          Published  2012
# 1637   Life expectancy at birth (years)          Published  2012
# 1777   Life expectancy at birth (years)          Published  2012
# 2840   Life expectancy at birth (years)          Published  2012
# 2915   Life expectancy at birth (years)          Published  2012
# 2935   Life expectancy at birth (years)          Published  2012
# 3241   Life expectancy at birth (years)          Published  2012
# 3247   Life expectancy at birth (years)          Published  2012
# 79     Life expectancy at birth (years)          Published  2012
# 446    Life expectancy at birth (years)          Published  2012
# 455    Life expectancy at birth (years)          Published  2012
# 499    Life expectancy at birth (years)          Published  2012
# 523    Life expectancy at birth (years)          Published  2012
# 544    Life expectancy at birth (years)          Published  2012
# 900    Life expectancy at birth (years)          Published  2012
# 946    Life expectancy at birth (years)          Published  2012
# 1742   Life expectancy at birth (years)          Published  2012
# 1765   Life expectancy at birth (years)          Published  2012
# 2852   Life expectancy at birth (years)          Published  2012
# 2911   Life expectancy at birth (years)          Published  2012
# 848    Life expectancy at birth (years)          Published  2012
# 875    Life expectancy at birth (years)          Published  2012
# 902    Life expectancy at birth (years)          Published  2012
# 1274   Life expectancy at birth (years)          Published  2012
# 1323   Life expectancy at birth (years)          Published  2012
# 1369   Life expectancy at birth (years)          Published  2012
# 2807   Life expectancy at birth (years)          Published  2012
# 1227   Life expectancy at birth (years)          Published  2012
# 1334   Life expectancy at birth (years)          Published  2012
# 1320   Life expectancy at birth (years)          Published  2012
#
#                 WHO_region  World Bank income group  \
# 1474                 Africa              Low-income
# 1476                 Africa              Low-income
# 1813                 Africa              Low-income
# 3071                 Africa              Low-income
# 577                  Africa              Low-income
# 3203        South-East Asia     Lower-middle-income
# 4275        Western Pacific     Lower-middle-income
# 604                  Africa              Low-income
# 686                  Africa     Lower-middle-income
# 991                  Africa              Low-income
# 1181        South-East Asia     Lower-middle-income
# 1631        South-East Asia     Lower-middle-income
# 1899                 Africa              Low-income
# 2033        Western Pacific     Lower-middle-income
# 2959  Eastern Mediterranean              Low-income
# 3079  Eastern Mediterranean              Low-income
# 3675        Western Pacific     Upper-middle-income
# 4454                 Africa     Upper-middle-income
# 177                  Africa              Low-income
# 242                  Africa              Low-income
# 252         South-East Asia              Low-income
# 563                  Africa              Low-income
# 565                  Africa              Low-income
# 574                  Africa              Low-income
# 613                  Africa              Low-income
# 649                  Africa              Low-income
# 783         South-East Asia     Lower-middle-income
# 968                  Africa              Low-income
# 982                  Africa              Low-income
# 993                  Africa              Low-income
# ...                     ...                     ...
# 1340                 Europe             High-income
# 1637                 Europe             High-income
# 1777        Western Pacific             High-income
# 2840                 Europe             High-income
# 2915        Western Pacific             High-income
# 2935                 Europe             High-income
# 3241               Americas     Upper-middle-income
# 3247               Americas     Upper-middle-income
# 79                   Europe             High-income
# 446                Americas             High-income
# 455                  Europe             High-income
# 499         Western Pacific             High-income
# 523         Western Pacific             High-income
# 544                  Europe             High-income
# 900                  Europe             High-income
# 946                  Europe             High-income
# 1742                 Europe             High-income
# 1765                 Europe             High-income
# 2852                 Europe             High-income
# 2911                 Europe             High-income
# 848                  Europe             High-income
# 875                  Europe             High-income
# 902                  Europe             High-income
# 1274                 Europe             High-income
# 1323        Western Pacific             High-income
# 1369        Western Pacific             High-income
# 2807        Western Pacific             High-income
# 1227                 Europe             High-income
# 1334                 Europe             High-income
# 1320        Western Pacific             High-income
#
#                                Country         Sex  Display_value  Numeric  \
# 1474                      Sierra Leone        Male             11     11.0
# 1476                      Sierra Leone      Female             11     11.0
# 1813                           Eritrea        Male             11     11.0
# 3071                      Sierra Leone  Both sexes             11     11.0
# 577                            Eritrea  Both sexes             12     12.0
# 3203                          Maldives      Female             12     12.0
# 4275                  Papua New Guinea        Male             12     12.0
# 604                            Liberia        Male             13     13.0
# 686                             Angola        Male             13     13.0
# 991                            Eritrea      Female             13     13.0
# 1181                          Maldives  Both sexes             13     13.0
# 1631                       Timor-Leste        Male             13     13.0
# 1899                              Chad        Male             13     13.0
# 2033                  Papua New Guinea  Both sexes             13     13.0
# 2959                       Afghanistan        Male             13     13.0
# 3079                       South Sudan        Male             13     13.0
# 3675                            Tuvalu        Male             13     13.0
# 4454                      South Africa        Male             13     13.0
# 177                            Comoros        Male             14     14.0
# 242                             Malawi        Male             14     14.0
# 252                              Nepal        Male             14     14.0
# 563                              Benin        Male             14     14.0
# 565                       Burkina Faso        Male             14     14.0
# 574   Democratic Republic of the Congo        Male             14     14.0
# 613                               Mali  Both sexes             14     14.0
# 649                               Chad  Both sexes             14     14.0
# 783                           Maldives        Male             14     14.0
# 968                            Burundi        Male             14     14.0
# 982           Central African Republic        Male             14     14.0
# 993                           Ethiopia        Male             14     14.0
# ...                                ...         ...            ...      ...
# 1340                       Netherlands      Female             83     83.0
# 1637                           Andorra  Both sexes             83     83.0
# 1777                         Singapore  Both sexes             83     83.0
# 2840                           Germany      Female             83     83.0
# 2915                             Nauru      Female             83     83.0
# 2935                        San Marino  Both sexes             83     83.0
# 3241                             Chile      Female             83     83.0
# 3247                          Colombia      Female             83     83.0
# 79                             Iceland      Female             84     84.0
# 446                             Canada      Female             84     84.0
# 455                             Cyprus      Female             84     84.0
# 499                              Japan  Both sexes             84     84.0
# 523                        New Zealand      Female             84     84.0
# 544                             Sweden      Female             84     84.0
# 900                             Israel      Female             84     84.0
# 946                         San Marino      Female             84     84.0
# 1742                        Luxembourg      Female             84     84.0
# 1765                          Portugal      Female             84     84.0
# 2852                           Finland      Female             84     84.0
# 2911                            Norway      Female             84     84.0
# 848                        Switzerland      Female             85     85.0
# 875                             France      Female             85     85.0
# 902                              Italy      Female             85     85.0
# 1274                             Spain      Female             85     85.0
# 1323                 Republic of Korea      Female             85     85.0
# 1369                         Singapore      Female             85     85.0
# 2807                         Australia      Female             85     85.0
# 1227                           Andorra      Female             86     86.0
# 1334                            Monaco      Female             86     86.0
# 1320                             Japan      Female             87     87.0
#
#       Low  High  Comments
# 1474  NaN   NaN       NaN
# 1476  NaN   NaN       NaN
# 1813  NaN   NaN       NaN
# 3071  NaN   NaN       NaN
# 577   NaN   NaN       NaN
# 3203  NaN   NaN       NaN
# 4275  NaN   NaN       NaN
# 604   NaN   NaN       NaN
# 686   NaN   NaN       NaN
# 991   NaN   NaN       NaN
# 1181  NaN   NaN       NaN
# 1631  NaN   NaN       NaN
# 1899  NaN   NaN       NaN
# 2033  NaN   NaN       NaN
# 2959  NaN   NaN       NaN
# 3079  NaN   NaN       NaN
# 3675  NaN   NaN       NaN
# 4454  NaN   NaN       NaN
# 177   NaN   NaN       NaN
# 242   NaN   NaN       NaN
# 252   NaN   NaN       NaN
# 563   NaN   NaN       NaN
# 565   NaN   NaN       NaN
# 574   NaN   NaN       NaN
# 613   NaN   NaN       NaN
# 649   NaN   NaN       NaN
# 783   NaN   NaN       NaN
# 968   NaN   NaN       NaN
# 982   NaN   NaN       NaN
# 993   NaN   NaN       NaN
# ...   ...   ...       ...
# 1340  NaN   NaN       NaN
# 1637  NaN   NaN       NaN
# 1777  NaN   NaN       NaN
# 2840  NaN   NaN       NaN
# 2915  NaN   NaN       NaN
# 2935  NaN   NaN       NaN
# 3241  NaN   NaN       NaN
# 3247  NaN   NaN       NaN
# 79    NaN   NaN       NaN
# 446   NaN   NaN       NaN
# 455   NaN   NaN       NaN
# 499   NaN   NaN       NaN
# 523   NaN   NaN       NaN
# 544   NaN   NaN       NaN
# 900   NaN   NaN       NaN
# 946   NaN   NaN       NaN
# 1742  NaN   NaN       NaN
# 1765  NaN   NaN       NaN
# 2852  NaN   NaN       NaN
# 2911  NaN   NaN       NaN
# 848   NaN   NaN       NaN
# 875   NaN   NaN       NaN
# 902   NaN   NaN       NaN
# 1274  NaN   NaN       NaN
# 1323  NaN   NaN       NaN
# 1369  NaN   NaN       NaN
# 2807  NaN   NaN       NaN
# 1227  NaN   NaN       NaN
# 1334  NaN   NaN       NaN
# 1320  NaN   NaN       NaN
#
# [4656 rows x 12 columns]

# %%
# 8. Make country as the first column of the dataframe.

# %%
df.columns
# Out:
# Index(['Indicator_id', 'Publication_status', 'Year', 'WHO_region ',
#        'World Bank income group', 'Country', 'Sex', 'Display_value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
col_2=['Country', 'Publication_status', 'Year', 'WHO_region ',
       'World Bank income group','Indicator_id', 'Sex', 'Display_value', 'Numeric',
       'Low', 'High', 'Comments']

# %%
df.reindex(columns=col_2)
# Out:
#                                  Country Publication_status  Year  \
# 0                                Andorra          Published  1990
# 1                                Andorra          Published  2000
# 2                                Andorra          Published  2012
# 3                                Andorra          Published  2000
# 4                   United Arab Emirates          Published  2012
# 5                    Antigua and Barbuda          Published  2000
# 6                    Antigua and Barbuda          Published  1990
# 7                    Antigua and Barbuda          Published  2012
# 8                              Australia          Published  2012
# 9                              Australia          Published  2000
# 10                             Australia          Published  2012
# 11                               Austria          Published  2012
# 12                               Austria          Published  2012
# 13                               Belgium          Published  2012
# 14                               Bahrain          Published  2000
# 15                               Bahrain          Published  1990
# 16                               Bahrain          Published  1990
# 17                               Bahamas          Published  2012
# 18                               Bahamas          Published  2000
# 19                              Barbados          Published  1990
# 20                              Barbados          Published  2012
# 21                              Barbados          Published  2012
# 22                     Brunei Darussalam          Published  1990
# 23                     Brunei Darussalam          Published  2000
# 24                     Brunei Darussalam          Published  2012
# 25                                Canada          Published  2000
# 26                                Canada          Published  2000
# 27                                Canada          Published  1990
# 28                           Switzerland          Published  1990
# 29                           Switzerland          Published  2012
# ...                                  ...                ...   ...
# 4626                              Serbia          Published  2012
# 4627                            Suriname          Published  2012
# 4628                              Sweden          Published  2012
# 4629                           Swaziland          Published  2012
# 4630                          Seychelles          Published  2000
# 4631                Syrian Arab Republic          Published  2000
# 4632                                Chad          Published  2012
# 4633                            Thailand          Published  2000
# 4634                            Thailand          Published  2000
# 4635                          Tajikistan          Published  2000
# 4636                          Tajikistan          Published  2012
# 4637                               Tonga          Published  2012
# 4638                 Trinidad and Tobago          Published  2012
# 4639                 Trinidad and Tobago          Published  2012
# 4640                             Tunisia          Published  2000
# 4641                              Tuvalu          Published  2012
# 4642                              Uganda          Published  2000
# 4643                             Ukraine          Published  2000
# 4644                             Uruguay          Published  2012
# 4645                             Uruguay          Published  2012
# 4646                             Uruguay          Published  2012
# 4647    Saint Vincent and the Grenadines          Published  2000
# 4648  Venezuela (Bolivarian Republic of)          Published  2012
# 4649                             Vanuatu          Published  2000
# 4650                               Samoa          Published  2012
# 4651                               Samoa          Published  2012
# 4652                               Yemen          Published  2012
# 4653                        South Africa          Published  2000
# 4654                              Zambia          Published  2000
# 4655                            Zimbabwe          Published  2012
#
#                 WHO_region  World Bank income group  \
# 0                    Europe             High-income
# 1                    Europe             High-income
# 2                    Europe             High-income
# 3                    Europe             High-income
# 4     Eastern Mediterranean             High-income
# 5                  Americas             High-income
# 6                  Americas             High-income
# 7                  Americas             High-income
# 8           Western Pacific             High-income
# 9           Western Pacific             High-income
# 10          Western Pacific             High-income
# 11                   Europe             High-income
# 12                   Europe             High-income
# 13                   Europe             High-income
# 14    Eastern Mediterranean             High-income
# 15    Eastern Mediterranean             High-income
# 16    Eastern Mediterranean             High-income
# 17                 Americas             High-income
# 18                 Americas             High-income
# 19                 Americas             High-income
# 20                 Americas             High-income
# 21                 Americas             High-income
# 22          Western Pacific             High-income
# 23          Western Pacific             High-income
# 24          Western Pacific             High-income
# 25                 Americas             High-income
# 26                 Americas             High-income
# 27                 Americas             High-income
# 28                   Europe             High-income
# 29                   Europe             High-income
# ...                     ...                     ...
# 4626                 Europe     Upper-middle-income
# 4627               Americas     Upper-middle-income
# 4628                 Europe             High-income
# 4629                 Africa     Lower-middle-income
# 4630                 Africa     Upper-middle-income
# 4631  Eastern Mediterranean     Lower-middle-income
# 4632                 Africa              Low-income
# 4633        South-East Asia     Lower-middle-income
# 4634        South-East Asia     Lower-middle-income
# 4635                 Europe              Low-income
# 4636                 Europe              Low-income
# 4637        Western Pacific     Lower-middle-income
# 4638               Americas             High-income
# 4639               Americas             High-income
# 4640  Eastern Mediterranean     Lower-middle-income
# 4641        Western Pacific     Upper-middle-income
# 4642                 Africa              Low-income
# 4643                 Europe     Lower-middle-income
# 4644               Americas     Upper-middle-income
# 4645               Americas     Upper-middle-income
# 4646               Americas     Upper-middle-income
# 4647               Americas     Upper-middle-income
# 4648               Americas     Upper-middle-income
# 4649        Western Pacific     Lower-middle-income
# 4650        Western Pacific     Lower-middle-income
# 4651        Western Pacific     Lower-middle-income
# 4652  Eastern Mediterranean              Low-income
# 4653                 Africa     Upper-middle-income
# 4654                 Africa              Low-income
# 4655                 Africa              Low-income
#
#                                          Indicator_id         Sex  \
# 0                    Life expectancy at birth (years)  Both sexes
# 1                    Life expectancy at birth (years)  Both sexes
# 2                   Life expectancy at age 60 (years)      Female
# 3                   Life expectancy at age 60 (years)  Both sexes
# 4                    Life expectancy at birth (years)      Female
# 5                    Life expectancy at birth (years)        Male
# 6                   Life expectancy at age 60 (years)        Male
# 7                   Life expectancy at age 60 (years)  Both sexes
# 8                    Life expectancy at birth (years)        Male
# 9                    Life expectancy at birth (years)  Both sexes
# 10                   Life expectancy at birth (years)  Both sexes
# 11                   Life expectancy at birth (years)      Female
# 12                  Life expectancy at age 60 (years)      Female
# 13                   Life expectancy at birth (years)      Female
# 14                   Life expectancy at birth (years)        Male
# 15                   Life expectancy at birth (years)      Female
# 16                  Life expectancy at age 60 (years)        Male
# 17                   Life expectancy at birth (years)        Male
# 18                  Life expectancy at age 60 (years)  Both sexes
# 19                   Life expectancy at birth (years)        Male
# 20                  Life expectancy at age 60 (years)      Female
# 21                  Life expectancy at age 60 (years)  Both sexes
# 22                  Life expectancy at age 60 (years)      Female
# 23                  Life expectancy at age 60 (years)      Female
# 24                  Life expectancy at age 60 (years)      Female
# 25                   Life expectancy at birth (years)      Female
# 26                  Life expectancy at age 60 (years)        Male
# 27                  Life expectancy at age 60 (years)      Female
# 28                   Life expectancy at birth (years)        Male
# 29                   Life expectancy at birth (years)  Both sexes
# ...                                               ...         ...
# 4626  Healthy life expectancy (HALE) at birth (years)      Female
# 4627  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4628  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4629  Healthy life expectancy (HALE) at birth (years)      Female
# 4630  Healthy life expectancy (HALE) at birth (years)        Male
# 4631  Healthy life expectancy (HALE) at birth (years)      Female
# 4632  Healthy life expectancy (HALE) at birth (years)      Female
# 4633  Healthy life expectancy (HALE) at birth (years)        Male
# 4634  Healthy life expectancy (HALE) at birth (years)      Female
# 4635  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4636  Healthy life expectancy (HALE) at birth (years)      Female
# 4637  Healthy life expectancy (HALE) at birth (years)      Female
# 4638  Healthy life expectancy (HALE) at birth (years)      Female
# 4639  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4640  Healthy life expectancy (HALE) at birth (years)        Male
# 4641  Healthy life expectancy (HALE) at birth (years)        Male
# 4642  Healthy life expectancy (HALE) at birth (years)      Female
# 4643  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4644  Healthy life expectancy (HALE) at birth (years)        Male
# 4645  Healthy life expectancy (HALE) at birth (years)      Female
# 4646  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4647  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4648  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4649  Healthy life expectancy (HALE) at birth (years)        Male
# 4650  Healthy life expectancy (HALE) at birth (years)        Male
# 4651  Healthy life expectancy (HALE) at birth (years)      Female
# 4652  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4653  Healthy life expectancy (HALE) at birth (years)        Male
# 4654  Healthy life expectancy (HALE) at birth (years)  Both sexes
# 4655  Healthy life expectancy (HALE) at birth (years)      Female
#
#       Display_value  Numeric  Low  High  Comments
# 0                77     77.0  NaN   NaN       NaN
# 1                80     80.0  NaN   NaN       NaN
# 2                28     28.0  NaN   NaN       NaN
# 3                23     23.0  NaN   NaN       NaN
# 4                78     78.0  NaN   NaN       NaN
# 5                72     72.0  NaN   NaN       NaN
# 6                17     17.0  NaN   NaN       NaN
# 7                22     22.0  NaN   NaN       NaN
# 8                81     81.0  NaN   NaN       NaN
# 9                80     80.0  NaN   NaN       NaN
# 10               83     83.0  NaN   NaN       NaN
# 11               83     83.0  NaN   NaN       NaN
# 12               25     25.0  NaN   NaN       NaN
# 13               83     83.0  NaN   NaN       NaN
# 14               73     73.0  NaN   NaN       NaN
# 15               74     74.0  NaN   NaN       NaN
# 16               17     17.0  NaN   NaN       NaN
# 17               72     72.0  NaN   NaN       NaN
# 18               21     21.0  NaN   NaN       NaN
# 19               71     71.0  NaN   NaN       NaN
# 20               25     25.0  NaN   NaN       NaN
# 21               23     23.0  NaN   NaN       NaN
# 22               20     20.0  NaN   NaN       NaN
# 23               22     22.0  NaN   NaN       NaN
# 24               21     21.0  NaN   NaN       NaN
# 25               82     82.0  NaN   NaN       NaN
# 26               21     21.0  NaN   NaN       NaN
# 27               24     24.0  NaN   NaN       NaN
# 28               74     74.0  NaN   NaN       NaN
# 29               83     83.0  NaN   NaN       NaN
# ...             ...      ...  ...   ...       ...
# 4626             67     67.0  NaN   NaN       NaN
# 4627             66     66.0  NaN   NaN       NaN
# 4628             72     72.0  NaN   NaN       NaN
# 4629             47     47.0  NaN   NaN       NaN
# 4630             61     61.0  NaN   NaN       NaN
# 4631             64     64.0  NaN   NaN       NaN
# 4632             44     44.0  NaN   NaN       NaN
# 4633             59     59.0  NaN   NaN       NaN
# 4634             65     65.0  NaN   NaN       NaN
# 4635             56     56.0  NaN   NaN       NaN
# 4636             60     60.0  NaN   NaN       NaN
# 4637             61     61.0  NaN   NaN       NaN
# 4638             64     64.0  NaN   NaN       NaN
# 4639             61     61.0  NaN   NaN       NaN
# 4640             63     63.0  NaN   NaN       NaN
# 4641             57     57.0  NaN   NaN       NaN
# 4642             40     40.0  NaN   NaN       NaN
# 4643             60     60.0  NaN   NaN       NaN
# 4644             65     65.0  NaN   NaN       NaN
# 4645             70     70.0  NaN   NaN       NaN
# 4646             68     68.0  NaN   NaN       NaN
# 4647             61     61.0  NaN   NaN       NaN
# 4648             66     66.0  NaN   NaN       NaN
# 4649             59     59.0  NaN   NaN       NaN
# 4650             62     62.0  NaN   NaN       NaN
# 4651             66     66.0  NaN   NaN       NaN
# 4652             54     54.0  NaN   NaN       NaN
# 4653             49     49.0  NaN   NaN       NaN
# 4654             36     36.0  NaN   NaN       NaN
# 4655             51     51.0  NaN   NaN       NaN
#
# [4656 rows x 12 columns]

# %%
# 9. Get the column array using a variable
np.ravel(df.Country)
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
np.ravel(df1.STATION)
# Out:
# array(['GHCND:GME00111445', 'GHCND:GME00111445', 'GHCND:GME00111445', ...,
#        'GHCND:GMM00010385', 'GHCND:GMM00010385', 'GHCND:GMM00010385'],
#       dtype=object)

# %%
# 10. Get the subset rows 11, 24, 37

# %%
df.loc[['11','24','37']]
# Out:
#                          Indicator_id Publication_status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#         WHO_region  World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display_value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %%
# 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
df.drop(['5', '12', '23','56'])
# Out:
#                                          Indicator_id Publication_status  \
# 0                    Life expectancy at birth (years)          Published
# 1                    Life expectancy at birth (years)          Published
# 2                   Life expectancy at age 60 (years)          Published
# 3                   Life expectancy at age 60 (years)          Published
# 4                    Life expectancy at birth (years)          Published
# 6                   Life expectancy at age 60 (years)          Published
# 7                   Life expectancy at age 60 (years)          Published
# 8                    Life expectancy at birth (years)          Published
# 9                    Life expectancy at birth (years)          Published
# 10                   Life expectancy at birth (years)          Published
# 11                   Life expectancy at birth (years)          Published
# 13                   Life expectancy at birth (years)          Published
# 14                   Life expectancy at birth (years)          Published
# 15                   Life expectancy at birth (years)          Published
# 16                  Life expectancy at age 60 (years)          Published
# 17                   Life expectancy at birth (years)          Published
# 18                  Life expectancy at age 60 (years)          Published
# 19                   Life expectancy at birth (years)          Published
# 20                  Life expectancy at age 60 (years)          Published
# 21                  Life expectancy at age 60 (years)          Published
# 22                  Life expectancy at age 60 (years)          Published
# 24                  Life expectancy at age 60 (years)          Published
# 25                   Life expectancy at birth (years)          Published
# 26                  Life expectancy at age 60 (years)          Published
# 27                  Life expectancy at age 60 (years)          Published
# 28                   Life expectancy at birth (years)          Published
# 29                   Life expectancy at birth (years)          Published
# 30                  Life expectancy at age 60 (years)          Published
# 31                   Life expectancy at birth (years)          Published
# 32                  Life expectancy at age 60 (years)          Published
# ...                                               ...                ...
# 4626  Healthy life expectancy (HALE) at birth (years)          Published
# 4627  Healthy life expectancy (HALE) at birth (years)          Published
# 4628  Healthy life expectancy (HALE) at birth (years)          Published
# 4629  Healthy life expectancy (HALE) at birth (years)          Published
# 4630  Healthy life expectancy (HALE) at birth (years)          Published
# 4631  Healthy life expectancy (HALE) at birth (years)          Published
# 4632  Healthy life expectancy (HALE) at birth (years)          Published
# 4633  Healthy life expectancy (HALE) at birth (years)          Published
# 4634  Healthy life expectancy (HALE) at birth (years)          Published
# 4635  Healthy life expectancy (HALE) at birth (years)          Published
# 4636  Healthy life expectancy (HALE) at birth (years)          Published
# 4637  Healthy life expectancy (HALE) at birth (years)          Published
# 4638  Healthy life expectancy (HALE) at birth (years)          Published
# 4639  Healthy life expectancy (HALE) at birth (years)          Published
# 4640  Healthy life expectancy (HALE) at birth (years)          Published
# 4641  Healthy life expectancy (HALE) at birth (years)          Published
# 4642  Healthy life expectancy (HALE) at birth (years)          Published
# 4643  Healthy life expectancy (HALE) at birth (years)          Published
# 4644  Healthy life expectancy (HALE) at birth (years)          Published
# 4645  Healthy life expectancy (HALE) at birth (years)          Published
# 4646  Healthy life expectancy (HALE) at birth (years)          Published
# 4647  Healthy life expectancy (HALE) at birth (years)          Published
# 4648  Healthy life expectancy (HALE) at birth (years)          Published
# 4649  Healthy life expectancy (HALE) at birth (years)          Published
# 4650  Healthy life expectancy (HALE) at birth (years)          Published
# 4651  Healthy life expectancy (HALE) at birth (years)          Published
# 4652  Healthy life expectancy (HALE) at birth (years)          Published
# 4653  Healthy life expectancy (HALE) at birth (years)          Published
# 4654  Healthy life expectancy (HALE) at birth (years)          Published
# 4655  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year            WHO_region  World Bank income group  \
# 0     1990                 Europe             High-income
# 1     2000                 Europe             High-income
# 2     2012                 Europe             High-income
# 3     2000                 Europe             High-income
# 4     2012  Eastern Mediterranean             High-income
# 6     1990               Americas             High-income
# 7     2012               Americas             High-income
# 8     2012        Western Pacific             High-income
# 9     2000        Western Pacific             High-income
# 10    2012        Western Pacific             High-income
# 11    2012                 Europe             High-income
# 13    2012                 Europe             High-income
# 14    2000  Eastern Mediterranean             High-income
# 15    1990  Eastern Mediterranean             High-income
# 16    1990  Eastern Mediterranean             High-income
# 17    2012               Americas             High-income
# 18    2000               Americas             High-income
# 19    1990               Americas             High-income
# 20    2012               Americas             High-income
# 21    2012               Americas             High-income
# 22    1990        Western Pacific             High-income
# 24    2012        Western Pacific             High-income
# 25    2000               Americas             High-income
# 26    2000               Americas             High-income
# 27    1990               Americas             High-income
# 28    1990                 Europe             High-income
# 29    2012                 Europe             High-income
# 30    2000                 Europe             High-income
# 31    2012        Western Pacific             High-income
# 32    2012        Western Pacific             High-income
# ...    ...                    ...                     ...
# 4626  2012                 Europe     Upper-middle-income
# 4627  2012               Americas     Upper-middle-income
# 4628  2012                 Europe             High-income
# 4629  2012                 Africa     Lower-middle-income
# 4630  2000                 Africa     Upper-middle-income
# 4631  2000  Eastern Mediterranean     Lower-middle-income
# 4632  2012                 Africa              Low-income
# 4633  2000        South-East Asia     Lower-middle-income
# 4634  2000        South-East Asia     Lower-middle-income
# 4635  2000                 Europe              Low-income
# 4636  2012                 Europe              Low-income
# 4637  2012        Western Pacific     Lower-middle-income
# 4638  2012               Americas             High-income
# 4639  2012               Americas             High-income
# 4640  2000  Eastern Mediterranean     Lower-middle-income
# 4641  2012        Western Pacific     Upper-middle-income
# 4642  2000                 Africa              Low-income
# 4643  2000                 Europe     Lower-middle-income
# 4644  2012               Americas     Upper-middle-income
# 4645  2012               Americas     Upper-middle-income
# 4646  2012               Americas     Upper-middle-income
# 4647  2000               Americas     Upper-middle-income
# 4648  2012               Americas     Upper-middle-income
# 4649  2000        Western Pacific     Lower-middle-income
# 4650  2012        Western Pacific     Lower-middle-income
# 4651  2012        Western Pacific     Lower-middle-income
# 4652  2012  Eastern Mediterranean              Low-income
# 4653  2000                 Africa     Upper-middle-income
# 4654  2000                 Africa              Low-income
# 4655  2012                 Africa              Low-income
#
#                                  Country         Sex  Display_value  Numeric  \
# 0                                Andorra  Both sexes             77     77.0
# 1                                Andorra  Both sexes             80     80.0
# 2                                Andorra      Female             28     28.0
# 3                                Andorra  Both sexes             23     23.0
# 4                   United Arab Emirates      Female             78     78.0
# 6                    Antigua and Barbuda        Male             17     17.0
# 7                    Antigua and Barbuda  Both sexes             22     22.0
# 8                              Australia        Male             81     81.0
# 9                              Australia  Both sexes             80     80.0
# 10                             Australia  Both sexes             83     83.0
# 11                               Austria      Female             83     83.0
# 13                               Belgium      Female             83     83.0
# 14                               Bahrain        Male             73     73.0
# 15                               Bahrain      Female             74     74.0
# 16                               Bahrain        Male             17     17.0
# 17                               Bahamas        Male             72     72.0
# 18                               Bahamas  Both sexes             21     21.0
# 19                              Barbados        Male             71     71.0
# 20                              Barbados      Female             25     25.0
# 21                              Barbados  Both sexes             23     23.0
# 22                     Brunei Darussalam      Female             20     20.0
# 24                     Brunei Darussalam      Female             21     21.0
# 25                                Canada      Female             82     82.0
# 26                                Canada        Male             21     21.0
# 27                                Canada      Female             24     24.0
# 28                           Switzerland        Male             74     74.0
# 29                           Switzerland  Both sexes             83     83.0
# 30                           Switzerland  Both sexes             23     23.0
# 31                          Cook Islands  Both sexes             76     76.0
# 32                          Cook Islands      Female             22     22.0
# ...                                  ...         ...            ...      ...
# 4626                              Serbia      Female             67     67.0
# 4627                            Suriname  Both sexes             66     66.0
# 4628                              Sweden  Both sexes             72     72.0
# 4629                           Swaziland      Female             47     47.0
# 4630                          Seychelles        Male             61     61.0
# 4631                Syrian Arab Republic      Female             64     64.0
# 4632                                Chad      Female             44     44.0
# 4633                            Thailand        Male             59     59.0
# 4634                            Thailand      Female             65     65.0
# 4635                          Tajikistan  Both sexes             56     56.0
# 4636                          Tajikistan      Female             60     60.0
# 4637                               Tonga      Female             61     61.0
# 4638                 Trinidad and Tobago      Female             64     64.0
# 4639                 Trinidad and Tobago  Both sexes             61     61.0
# 4640                             Tunisia        Male             63     63.0
# 4641                              Tuvalu        Male             57     57.0
# 4642                              Uganda      Female             40     40.0
# 4643                             Ukraine  Both sexes             60     60.0
# 4644                             Uruguay        Male             65     65.0
# 4645                             Uruguay      Female             70     70.0
# 4646                             Uruguay  Both sexes             68     68.0
# 4647    Saint Vincent and the Grenadines  Both sexes             61     61.0
# 4648  Venezuela (Bolivarian Republic of)  Both sexes             66     66.0
# 4649                             Vanuatu        Male             59     59.0
# 4650                               Samoa        Male             62     62.0
# 4651                               Samoa      Female             66     66.0
# 4652                               Yemen  Both sexes             54     54.0
# 4653                        South Africa        Male             49     49.0
# 4654                              Zambia  Both sexes             36     36.0
# 4655                            Zimbabwe      Female             51     51.0
#
#       Low  High  Comments
# 0     NaN   NaN       NaN
# 1     NaN   NaN       NaN
# 2     NaN   NaN       NaN
# 3     NaN   NaN       NaN
# 4     NaN   NaN       NaN
# 6     NaN   NaN       NaN
# 7     NaN   NaN       NaN
# 8     NaN   NaN       NaN
# 9     NaN   NaN       NaN
# 10    NaN   NaN       NaN
# 11    NaN   NaN       NaN
# 13    NaN   NaN       NaN
# 14    NaN   NaN       NaN
# 15    NaN   NaN       NaN
# 16    NaN   NaN       NaN
# 17    NaN   NaN       NaN
# 18    NaN   NaN       NaN
# 19    NaN   NaN       NaN
# 20    NaN   NaN       NaN
# 21    NaN   NaN       NaN
# 22    NaN   NaN       NaN
# 24    NaN   NaN       NaN
# 25    NaN   NaN       NaN
# 26    NaN   NaN       NaN
# 27    NaN   NaN       NaN
# 28    NaN   NaN       NaN
# 29    NaN   NaN       NaN
# 30    NaN   NaN       NaN
# 31    NaN   NaN       NaN
# 32    NaN   NaN       NaN
# ...   ...   ...       ...
# 4626  NaN   NaN       NaN
# 4627  NaN   NaN       NaN
# 4628  NaN   NaN       NaN
# 4629  NaN   NaN       NaN
# 4630  NaN   NaN       NaN
# 4631  NaN   NaN       NaN
# 4632  NaN   NaN       NaN
# 4633  NaN   NaN       NaN
# 4634  NaN   NaN       NaN
# 4635  NaN   NaN       NaN
# 4636  NaN   NaN       NaN
# 4637  NaN   NaN       NaN
# 4638  NaN   NaN       NaN
# 4639  NaN   NaN       NaN
# 4640  NaN   NaN       NaN
# 4641  NaN   NaN       NaN
# 4642  NaN   NaN       NaN
# 4643  NaN   NaN       NaN
# 4644  NaN   NaN       NaN
# 4645  NaN   NaN       NaN
# 4646  NaN   NaN       NaN
# 4647  NaN   NaN       NaN
# 4648  NaN   NaN       NaN
# 4649  NaN   NaN       NaN
# 4650  NaN   NaN       NaN
# 4651  NaN   NaN       NaN
# 4652  NaN   NaN       NaN
# 4653  NaN   NaN       NaN
# 4654  NaN   NaN       NaN
# 4655  NaN   NaN       NaN
#
# [4652 rows x 12 columns]

# %%
users=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv' )

# %%
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv' )

# %%
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv' )

# %%
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.columns
sessions.columns
products.columns
transactions.columns
# Out:
# Index(['TransactionID', 'TransactionDate', 'UserID', 'ProductID', 'Quantity'], dtype='object')

# %%
users.columns
# Out:
# Index(['UserID', 'User', 'Gender', 'Registered', 'Cancelled'], dtype='object')

# %%
sessions.columns
# Out:
# Index(['SessionID', 'SessionDate', 'UserID'], dtype='object')

# %%
products.columns
# Out:
# Index(['ProductID', 'Product', 'Price'], dtype='object')

# %%
transactions.columns
# Out:
# Index(['TransactionID', 'TransactionDate', 'UserID', 'ProductID', 'Quantity'], dtype='object')

# %%
# 12. Join users to transactions,keeping all rows from transactions and only matching rows from users (left join)

# %%
result=pd.merge(transactions,users,on='UserID',how='left')

# %%
result
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08
# 5    male  2010-08-01  2010-08-08
# 6  female  2012-10-23  2016-06-07
# 7     NaN         NaN         NaN
# 8     NaN         NaN         NaN
# 9  female  2012-10-23  2016-06-07

# %%
# 13. Which transactions have a UserID not in users?
result.columns
# Out:
# Index(['TransactionID', 'TransactionDate', 'UserID', 'ProductID', 'Quantity',
#        'User', 'Gender', 'Registered', 'Cancelled'],
#       dtype='object')

# %%
# 14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

# %%
result1=pd.merge(transactions,users,on='UserID',how='inner')

# %%
result1
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
# 15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

# %%
result2=pd.merge(transactions,users,on='UserID',how='outer')

# %%
result2
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
#     Gender  Registered   Cancelled
# 0      NaN         NaN         NaN
# 1      NaN         NaN         NaN
# 2   female  2012-10-23  2016-06-07
# 3   female  2012-10-23  2016-06-07
# 4   female  2012-10-23  2016-06-07
# 5   female  2012-10-23  2016-06-07
# 6     male  2012-12-21         NaN
# 7     male  2010-08-01  2010-08-08
# 8     male  2010-08-01  2010-08-08
# 9      NaN         NaN         NaN
# 10  female  2013-07-17         NaN
# 11    male  2010-11-25         NaN

# %%
# 16. Determine which sessions occurred on the same day each user registered Expected

# %%
pd.merge(left=users, right=sessions, how='inner', left_on=['UserID', 'Registered'], right_on=['UserID', 'SessionDate'])
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %%
# 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
df1 = pd.DataFrame({'key': np.repeat(1, users.shape[0]), 'UserID': users.UserID})
df2 = pd.DataFrame({'key': np.repeat(1, products.shape[0]), 'ProductID': products.ProductID})
pd.merge(df1, df2,on='key')[['UserID', 'ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
# 18. Determine how much quantity of each product was purchased by each user

# %%
df1 = pd.DataFrame({'key': np.repeat(1, users.shape[0]), 'UserID': users.UserID})
df2 = pd.DataFrame({'key': np.repeat(1, products.shape[0]), 'ProductID': products.ProductID})
user_products = pd.merge(df1, df2,on='key')[['UserID', 'ProductID']]
pd.merge(user_products, transactions, how='left', on=['UserID', 'ProductID'])
# Out:
#     UserID  ProductID  TransactionID TransactionDate  Quantity
# 0        1          1            NaN             NaN       NaN
# 1        1          2            4.0      2012-08-26       3.0
# 2        1          3            NaN             NaN       NaN
# 3        1          4            NaN             NaN       NaN
# 4        1          5            NaN             NaN       NaN
# 5        2          1            NaN             NaN       NaN
# 6        2          2            NaN             NaN       NaN
# 7        2          3            NaN             NaN       NaN
# 8        2          4            5.0      2013-06-06       1.0
# 9        2          5            6.0      2013-12-23       6.0
# 10       3          1            NaN             NaN       NaN
# 11       3          2            NaN             NaN       NaN
# 12       3          3            3.0      2011-06-16       1.0
# 13       3          4            2.0      2011-05-26       1.0
# 14       3          4            7.0      2013-12-30       1.0
# 15       3          4           10.0      2016-05-08       4.0
# 16       3          5            NaN             NaN       NaN
# 17       4          1            NaN             NaN       NaN
# 18       4          2            NaN             NaN       NaN
# 19       4          3            NaN             NaN       NaN
# 20       4          4            NaN             NaN       NaN
# 21       4          5            NaN             NaN       NaN
# 22       5          1            NaN             NaN       NaN
# 23       5          2            NaN             NaN       NaN
# 24       5          3            NaN             NaN       NaN
# 25       5          4            NaN             NaN       NaN
# 26       5          5            NaN             NaN       NaN

# %%
#19. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)

# %%
pd.merge(transactions, transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# 12                7        2013-12-30     3.0            4           1
# 13                7        2013-12-30     3.0            4           1
# 14                7        2013-12-30     3.0            4           1
# 15                7        2013-12-30     3.0            4           1
# 16               10        2016-05-08     3.0            4           4
# 17               10        2016-05-08     3.0            4           4
# 18               10        2016-05-08     3.0            4           4
# 19               10        2016-05-08     3.0            4           4
# 20                4        2012-08-26     1.0            2           3
# 21                5        2013-06-06     2.0            4           1
# 22                5        2013-06-06     2.0            4           1
# 23                6        2013-12-23     2.0            5           6
# 24                6        2013-12-23     2.0            5           6
# 25                8        2014-04-24     NaN            2           3
#
#     TransactionID_y TransactionDate_y  ProductID_y  Quantity_y
# 0                 1        2010-08-21            2           1
# 1                 9        2015-04-24            4           3
# 2                 1        2010-08-21            2           1
# 3                 9        2015-04-24            4           3
# 4                 2        2011-05-26            4           1
# 5                 3        2011-06-16            3           1
# 6                 7        2013-12-30            4           1
# 7                10        2016-05-08            4           4
# 8                 2        2011-05-26            4           1
# 9                 3        2011-06-16            3           1
# 10                7        2013-12-30            4           1
# 11               10        2016-05-08            4           4
# 12                2        2011-05-26            4           1
# 13                3        2011-06-16            3           1
# 14                7        2013-12-30            4           1
# 15               10        2016-05-08            4           4
# 16                2        2011-05-26            4           1
# 17                3        2011-06-16            3           1
# 18                7        2013-12-30            4           1
# 19               10        2016-05-08            4           4
# 20                4        2012-08-26            2           3
# 21                5        2013-06-06            4           1
# 22                6        2013-12-23            5           6
# 23                5        2013-06-06            4           1
# 24                6        2013-12-23            5           6
# 25                8        2014-04-24            2           3

# %%
# 20. Join each user to his/her first occuring transaction in the transactions table

# %%
pd.merge(users, transactions.groupby('UserID').first().reset_index(),how='left')
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %%
#21. Test to see if we can drop columns
# Code with Output

# %%
my_columns = list(result.columns) my_columns['UserID', 'User', 'Gender', 'Registered', 'Cancelled', 'TransactionID','TransactionDate','ProductID', 'Quantity'] 
list(data.dropna(thresh=int(result.shape[0] * .9), axis=1).columns)
# Out:
#   File "<ipython-input-161-57b3708d3787>", line 1
#     my_columns = list(result.columns) my_columns['UserID', 'User', 'Gender', 'Registered', 'Cancelled', 'TransactionID','TransactionDate','ProductID', 'Quantity']
#                                                ^
# SyntaxError: invalid syntax

# %%
#set threshold to drop NAs
['UserID', 'User', 'Gender', 'Registered'] missing_info = list(data.columns[data.isnull().any()]) missing_info[['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID','Quantity']]
# Out:
#   File "<ipython-input-168-c71577fe1f9b>", line 2
#     ['UserID', 'User', 'Gender', 'Registered'] missing_info = list(data.columns[data.isnull().any()]) missing_info[['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID','Quantity']]
#                                                           ^
# SyntaxError: invalid syntax

# %%
#for col in missing_info:
num_missing = result[result[col].isnull() == True].shape[0] column {}: {}'.format(col, num_missing)) #count of missing data
for col in missing_info:
print('number missing for
percent_missing = result[result[col].isnull() == True].shape[0] / result.shape[0] print('percent missing for column {}: {}'.format( col, percent_missing))
# Out:
#   File "<ipython-input-169-bb3dfa98231a>", line 2
#     num_missing = result[result[col].isnull() == True].shape[0] column {}: {}'.format(col, num_missing)) #count of missing data
#                                                                      ^
# SyntaxError: invalid syntax
